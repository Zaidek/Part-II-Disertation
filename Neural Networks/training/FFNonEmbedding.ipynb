# %%
# import standard libraries
import os
import numpy as np
import sys

import warnings
import pandas as pd

from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

import datetime
import pickle
from nltk.corpus import stopwords
import re
import regex
import string
from urllib.parse import urlparse

# %%
# import ML libraries
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import Dataset
from sklearn.metrics import f1_score

# %%
# import dataset and models used
sys.path.insert(0, '//wsl$/Ubuntu/home/zaidek/Part-II-Disertation/Neural Networks')
from ipynb.fs.defs.datasets import NonEmbeddingDataset
from ipynb.fs.defs.models import FFNonEmbedding
from ipynb.fs.defs.FFtraining import train_model_bert
from ipynb.fs.defs.FFtraining import define_sampler

# %%
# import training data
with open("../data/data_train", "rb") as fb:
    training_data = pickle.load(fb)

# import validation data
with open("../data/data_valid", "rb") as fb:
    validation_data = pickle.load(fb)

# %%
# try set gpu as training device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
device = "cpu"
# Out:
# cuda

# %%
# reindex data
train_data_indexed = training_data.reset_index(drop=True)
valid_data_indexed = validation_data.reset_index(drop=True)

# %%
# define cols which are used in model
req_cols = ["title", "text", "url", "time", "descendants"]

# %%
# extract specific cols needed
scores = train_data_indexed.score
training_data_indexed = train_data_indexed[req_cols]

validation_scores = valid_data_indexed.score
validation_data_indexed = valid_data_indexed[req_cols]

# %%
# fill nan values in normal data
training_data_indexed.title = training_data_indexed.title.fillna("")
training_data_indexed.text = training_data_indexed.text.fillna("")
training_data_indexed.url = training_data_indexed.url.fillna("")
training_data_indexed.time = training_data_indexed.time.fillna(0)
training_data_indexed.descendants = training_data_indexed.descendants.fillna(0)

validation_data_indexed.title = validation_data_indexed.title.fillna("")
validation_data_indexed.text = validation_data_indexed.text.fillna("")
validation_data_indexed.url = validation_data_indexed.url.fillna("")
validation_data_indexed.time = validation_data_indexed.time.fillna(0)
validation_data_indexed.descendants = validation_data_indexed.descendants.fillna(0)

# %%
# define loader parameters
cutoff = 20
batch_size = 64
num_epochs = 5

train_sampler = define_sampler(scores, cutoff)
valid_sampler = define_sampler(validation_scores, cutoff)

# %%
# create bert embedding datasets
dataset_train = NonEmbeddingDataset(training_data_indexed, scores, cutoff)
dataset_valid = NonEmbeddingDataset(validation_data_indexed, validation_scores, cutoff)

# %%
# define batched bert embedding loaders
use_sampler = False
train_loader, valid_loader = None, None
if use_sampler:
    train_loader = torch.utils.data.DataLoader(dataset=dataset_train, batch_size=batch_size, sampler=train_sampler)
    valid_loader = torch.utils.data.DataLoader(dataset=dataset_valid, batch_size=batch_size, sampler=valid_sampler)
else:
    train_loader = torch.utils.data.DataLoader(dataset=dataset_train, batch_size=batch_size, shuffle=True)
    valid_loader = torch.utils.data.DataLoader(dataset=dataset_valid, batch_size=batch_size, shuffle=True)

# %%
# define dimensions of bert model
input_dim = 8
output_dim = 1

# instantiate bert model
model = FFNonEmbedding(output_dim, input_dim)

# %%
# define loss function
loss_func = nn.BCEWithLogitsLoss()

# define paramters for optimizers
learning_rate = 0.01

# define basic optimizer class
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
# train model
model_final, train_losses, valid_losses = train_model_bert(model, train_loader, valid_loader, loss_func, optimizer, device, num_epochs)
# Out:
# Epoch 0.
# Iteration 100. Current Min Loss 1.913975426480174. Running F1 0.18060826669778077.
# Iteration 200. Current Min Loss 0.1577922039339319. Running F1 0.6025077634783513.
# Iteration 300. Current Min Loss 0.13702458601677792. Running F1 0.674258992469518.
# Iteration 400. Current Min Loss 0.09911089092027396. Running F1 0.7537086553797075.
# Iteration 500. Current Min Loss 0.12762739507481455. Running F1 0.7290637053005469.
# Iteration 600. Current Min Loss 0.10747203032951802. Running F1 0.7366678044178039.
# Iteration 700. Current Min Loss 0.10366004472016357. Running F1 0.7918350538350534.
# Iteration 800. Current Min Loss 0.12251333357504336. Running F1 0.7536077333742967.
# Iteration 900. Current Min Loss 0.10238334556110203. Running F1 0.72246905218964.
# Iteration 1000. Current Min Loss 0.1010041024396196. Running F1 0.7632970145609461.
# Iteration 1100. Current Min Loss 0.10825303668156266. Running F1 0.7617843884701463.
# Iteration 1200. Current Min Loss 0.0980793597176671. Running F1 0.7842106481559294.
# Iteration 1300. Current Min Loss 0.09951728973537684. Running F1 0.7904144287085458.
# Iteration 1400. Current Min Loss 0.07952915609814226. Running F1 0.8071582682023855.
# Iteration 1500. Current Min Loss 0.3536400582335773. Running F1 0.5708820030556546.
# Iteration 1600. Current Min Loss 0.10816464664065278. Running F1 0.7779822971146494.
# Iteration 1700. Current Min Loss 0.10822713681962341. Running F1 0.7637932002637882.
# Iteration 1800. Current Min Loss 0.09081283935345709. Running F1 0.8060344179832668.
# Iteration 1900. Current Min Loss 0.08019501338014379. Running F1 0.818661774929576.
# Iteration 2000. Current Min Loss 0.09788869382813573. Running F1 0.8078751112186292.
# Iteration 2100. Current Min Loss 0.09627148440573365. Running F1 0.7906932551452671.
# Iteration 2200. Current Min Loss 0.0886371107120067. Running F1 0.8052455044955039.
# Iteration 2300. Current Min Loss 0.09282326356507838. Running F1 0.8219261029648021.
# Iteration 2400. Current Min Loss 0.08649922782555222. Running F1 0.809853643776244.
# Iteration 2500. Current Min Loss 0.10607494244351984. Running F1 0.7744567508514872.
# Iteration 2600. Current Min Loss 0.0800368114374578. Running F1 0.8061754830137177.
# Iteration 2700. Current Min Loss 0.0841184184816666. Running F1 0.8492027764117541.
# Iteration 2800. Current Min Loss 0.09591898640617728. Running F1 0.8001253187816648.
# Iteration 2900. Current Min Loss 0.0830850437283516. Running F1 0.7987032265120492.
# Iteration 3000. Current Min Loss 0.09207296718843282. Running F1 0.8071225001348833.
# Iteration 3100. Current Min Loss 0.08291800495935604. Running F1 0.7706653477241708.
# Iteration 3200. Current Min Loss 0.07987222641706467. Running F1 0.8166338416485469.
# Iteration 3300. Current Min Loss 0.0782088633812964. Running F1 0.8166229342552868.
# Iteration 3400. Current Min Loss 0.0910187986236997. Running F1 0.7901133254430462.
# Iteration 3500. Current Min Loss 0.07698183428263292. Running F1 0.8276281485112752.
# Iteration 3600. Current Min Loss 0.07481176278088242. Running F1 0.7970656272280983.
# Iteration 3700. Current Min Loss 0.08232501627877355. Running F1 0.7930871469431838.
# Iteration 3800. Current Min Loss 0.07267928501591087. Running F1 0.8229275146937681.
# Iteration 3900. Current Min Loss 0.09033700737170874. Running F1 0.8232532382366134.
# Iteration 4000. Current Min Loss 0.0802474298980087. Running F1 0.8189416370523176.
# Iteration 4100. Current Min Loss 0.07969809758942574. Running F1 0.8128427095780029.
# Iteration 4200. Current Min Loss 0.07455280041787773. Running F1 0.8268773703420755.
# Iteration 4300. Current Min Loss 0.09513915745730628. Running F1 0.771669841252658.
# Iteration 4400. Current Min Loss 0.08354770632111468. Running F1 0.8247644117148757.
# Iteration 4500. Current Min Loss 0.07938273232197389. Running F1 0.8220742375099955.
# Iteration 4600. Current Min Loss 0.08838611666345969. Running F1 0.7936325733090436.
# Iteration 4700. Current Min Loss 0.08161363143473864. Running F1 0.7807725914436433.
# Iteration 4800. Current Min Loss 0.08214446758385748. Running F1 0.8039416186668505.
# Iteration 4900. Current Min Loss 0.08742745356168598. Running F1 0.7911399200214986.
# Iteration 5000. Current Min Loss 0.09862177076749504. Running F1 0.7962617828507917.
# Iteration 5100. Current Min Loss 0.074802340073511. Running F1 0.8287090077105552.
# Iteration 5200. Current Min Loss 0.08895708567462862. Running F1 0.8139373952650298.
# Iteration 5300. Current Min Loss 0.08400962027255446. Running F1 0.7968715206362259.
# Iteration 5400. Current Min Loss 0.09007696839049459. Running F1 0.8061107730418868.
# Iteration 5500. Current Min Loss 0.09056450767442584. Running F1 0.7964763798293206.
# Iteration 5600. Current Min Loss 0.07865932627115399. Running F1 0.8252729838101348.
# Iteration 5700. Current Min Loss 0.0760953096486628. Running F1 0.8100323247443985.
# Iteration 5800. Current Min Loss 0.08403570871800184. Running F1 0.7905053280053274.
# Iteration 5900. Current Min Loss 0.08312639245705214. Running F1 0.8341600991028233.
# Iteration 6000. Current Min Loss 0.08456581239588559. Running F1 0.7976529759370312.
# Iteration 6100. Current Min Loss 0.0833659683028236. Running F1 0.820607770368606.
# Iteration 6200. Current Min Loss 0.07575412487611174. Running F1 0.8073427473776573.
# Iteration 6300. Current Min Loss 0.07666923064738512. Running F1 0.8032326023649545.
# Iteration 6400. Current Min Loss 0.07646516473963856. Running F1 0.8358123863580517.
# Iteration 6500. Current Min Loss 0.09266367845237256. Running F1 0.7753596697420221.
# Iteration 6600. Current Min Loss 0.07930468568112702. Running F1 0.7869951708422296.
# Iteration 6700. Current Min Loss 0.07207709545909893. Running F1 0.8217890047277916.
# Iteration 6800. Current Min Loss 0.07610567691735923. Running F1 0.8092165796020281.
# Iteration 6900. Current Min Loss 0.07385086572729051. Running F1 0.8043513267777971.
# Iteration 7000. Current Min Loss 0.07932895020232536. Running F1 0.8179221687325402.
# Iteration 7100. Current Min Loss 0.07904897674918175. Running F1 0.7990115385130858.
# Iteration 7200. Current Min Loss 0.08317450164817274. Running F1 0.7785855706527057.
# Iteration 7300. Current Min Loss 0.08042226935271174. Running F1 0.8225517541797727.
# Iteration 7400. Current Min Loss 0.08198792332783342. Running F1 0.799774318818436.
# Iteration 7500. Current Min Loss 0.08318155542947352. Running F1 0.7878597244277682.
# Iteration 7600. Current Min Loss 0.08191585666965694. Running F1 0.8257552853922817.
# vloss - 77.31506195734255
# Epoch 1.
# Iteration 100. Current Min Loss 0.07522717856802047. Running F1 0.8260568637588753.
# Iteration 200. Current Min Loss 0.08879880039952695. Running F1 0.7648449818155696.
# Iteration 300. Current Min Loss 0.06643114187754691. Running F1 0.8205851956780744.
# Iteration 400. Current Min Loss 0.08445927761495113. Running F1 0.8115104330541802.
# Iteration 500. Current Min Loss 0.07218450795393437. Running F1 0.8131744713319012.
# Iteration 600. Current Min Loss 0.07930434424197301. Running F1 0.7923218150958086.
# Iteration 700. Current Min Loss 0.07351358035113663. Running F1 0.8229835224974539.
# Iteration 800. Current Min Loss 0.07527007925324142. Running F1 0.831155854379538.
# Iteration 900. Current Min Loss 0.08155760879162699. Running F1 0.7911697232935618.
# Iteration 1000. Current Min Loss 0.08885616491315887. Running F1 0.7915675562715196.
# Iteration 1100. Current Min Loss 0.08295431608334183. Running F1 0.7973081332600781.
# Iteration 1200. Current Min Loss 0.08079291732981801. Running F1 0.8101030220209782.
# Iteration 1300. Current Min Loss 0.09622713265474886. Running F1 0.7686141080281943.
# Iteration 1400. Current Min Loss 0.07613835031166673. Running F1 0.7762372070653799.
# Iteration 1500. Current Min Loss 0.0725538239069283. Running F1 0.7687156144509077.
# Iteration 1600. Current Min Loss 0.07661515405401588. Running F1 0.8056505833347933.
# Iteration 1700. Current Min Loss 0.07510787151288241. Running F1 0.8340376811011485.
# Iteration 1800. Current Min Loss 0.0857484947075136. Running F1 0.782646213050944.
# Iteration 1900. Current Min Loss 0.08382074338383973. Running F1 0.7898786297981338.
# Iteration 2000. Current Min Loss 0.0847526737023145. Running F1 0.8082673958308626.
# Iteration 2100. Current Min Loss 0.08033616439672187. Running F1 0.7677051786362926.
# Iteration 2200. Current Min Loss 0.09020400539971889. Running F1 0.7875300507026508.
# Iteration 2300. Current Min Loss 0.08070619280450046. Running F1 0.8084372717066212.
# Iteration 2400. Current Min Loss 0.08676003536209465. Running F1 0.7797060716201579.
# Iteration 2500. Current Min Loss 0.07386027369648218. Running F1 0.8191957877004316.
# Iteration 2600. Current Min Loss 0.07611186125781387. Running F1 0.7985845492656638.
# Iteration 2700. Current Min Loss 0.07185396650223992. Running F1 0.806910599204716.
# Iteration 2800. Current Min Loss 0.0861385827511549. Running F1 0.8009083731026447.
# Iteration 2900. Current Min Loss 0.08374081701040267. Running F1 0.7862444834595856.
# Iteration 3000. Current Min Loss 0.08615525269880892. Running F1 0.7662531676270059.
# Iteration 3100. Current Min Loss 0.07550884150434285. Running F1 0.7931236012869134.
# Iteration 3200. Current Min Loss 0.07889404182787985. Running F1 0.793568408715467.
# Iteration 3300. Current Min Loss 0.07604990711901337. Running F1 0.8173425145545882.
# Iteration 3400. Current Min Loss 0.07204538867343217. Running F1 0.828825465212462.
# Iteration 3500. Current Min Loss 0.07197141536977142. Running F1 0.8093585215953631.
# Iteration 3600. Current Min Loss 0.07371764909243211. Running F1 0.8459324217682671.
# Iteration 3700. Current Min Loss 0.07912862894125283. Running F1 0.8275376780082659.
# Iteration 3800. Current Min Loss 0.0746459210338071. Running F1 0.8006285128699981.
# Iteration 3900. Current Min Loss 0.07789721136447042. Running F1 0.8133960103364124.
# Iteration 4000. Current Min Loss 0.08605625596363098. Running F1 0.7684847924693119.
# Iteration 4100. Current Min Loss 0.08884284645784646. Running F1 0.7674487123232574.
# Iteration 4200. Current Min Loss 0.0749024302046746. Running F1 0.8073277868502327.
# Iteration 4300. Current Min Loss 0.08242698546499014. Running F1 0.8024365954822608.
# Iteration 4400. Current Min Loss 0.08231078480836004. Running F1 0.8121541571603486.
# Iteration 4500. Current Min Loss 0.08680946801323444. Running F1 0.7838090928679159.
# Iteration 4600. Current Min Loss 0.0887599575938657. Running F1 0.7763848586054466.
# Iteration 4700. Current Min Loss 0.07511313179042191. Running F1 0.8133395080152042.
# Iteration 4800. Current Min Loss 0.07971208248054609. Running F1 0.7977166322669414.
# Iteration 4900. Current Min Loss 0.07597066133050248. Running F1 0.7964891256983391.
# Iteration 5000. Current Min Loss 0.07402759079355746. Running F1 0.8474196292183902.
# Iteration 5100. Current Min Loss 0.0707891002856195. Running F1 0.8207648658531005.
# Iteration 5200. Current Min Loss 0.07138790813274681. Running F1 0.8236834570658096.
# Iteration 5300. Current Min Loss 0.08279675216879695. Running F1 0.7930429242240389.
# Iteration 5400. Current Min Loss 0.07279026770498603. Running F1 0.8293395012280458.
# Iteration 5500. Current Min Loss 0.06948024589335546. Running F1 0.8161151358960952.
# Iteration 5600. Current Min Loss 0.07161075685173274. Running F1 0.7835097743673595.
# Iteration 5700. Current Min Loss 0.0861987964832224. Running F1 0.8131795181232517.
# Iteration 5800. Current Min Loss 0.07980188586749136. Running F1 0.795369848892227.
# Iteration 5900. Current Min Loss 0.07714992568828166. Running F1 0.8199843418535363.
# Iteration 6000. Current Min Loss 0.07143741443753243. Running F1 0.7719207681723157.
# Iteration 6100. Current Min Loss 0.0643027474777773. Running F1 0.8439848876613578.
# Iteration 6200. Current Min Loss 0.07864963215775787. Running F1 0.819143325542706.
# Iteration 6300. Current Min Loss 0.07990710100624711. Running F1 0.8039553363732925.
# Iteration 6400. Current Min Loss 0.08108411043416709. Running F1 0.8209379946828121.
# Iteration 6500. Current Min Loss 0.0793535894760862. Running F1 0.7996622087063259.
# Iteration 6600. Current Min Loss 0.08457428799942136. Running F1 0.7826337486043365.
# Iteration 6700. Current Min Loss 0.0803211475070566. Running F1 0.7936045013637887.
# Iteration 6800. Current Min Loss 0.08812064460013062. Running F1 0.8000207809046812.
# Iteration 6900. Current Min Loss 0.08545169341377915. Running F1 0.8027101079175378.
# Iteration 7000. Current Min Loss 0.07545178271248006. Running F1 0.818687816139828.
# Iteration 7100. Current Min Loss 0.08170347566716372. Running F1 0.8013120957989378.
# Iteration 7200. Current Min Loss 0.08300837449263782. Running F1 0.7869729059658722.
# Iteration 7300. Current Min Loss 0.0775026955921203. Running F1 0.8128823733474758.
# Iteration 7400. Current Min Loss 0.08012795093469322. Running F1 0.8262033275462062.
# Iteration 7500. Current Min Loss 0.07934640341321937. Running F1 0.8097365486250929.
# Iteration 7600. Current Min Loss 0.07866219270043075. Running F1 0.7829601659090817.
# vloss - 73.91900086868554
# Epoch 2.
# Iteration 100. Current Min Loss 0.07356398709118367. Running F1 0.8427535799082234.
# Iteration 200. Current Min Loss 0.06803017708938569. Running F1 0.8105292583233755.
# Iteration 300. Current Min Loss 0.08365786864189431. Running F1 0.8038415521676388.
# Iteration 400. Current Min Loss 0.07807954424060881. Running F1 0.8021516421315177.
# Iteration 500. Current Min Loss 0.082940119728446. Running F1 0.8039557027939374.
# Iteration 600. Current Min Loss 0.0772065691743046. Running F1 0.78646648561277.
# Iteration 700. Current Min Loss 0.07728314032778144. Running F1 0.7901076454505241.
# Iteration 800. Current Min Loss 0.0859746220894158. Running F1 0.7958449428258281.
# Iteration 900. Current Min Loss 0.07446363527327776. Running F1 0.8060586374409898.
# Iteration 1000. Current Min Loss 0.08306361335562543. Running F1 0.8159030805795509.
# Iteration 1100. Current Min Loss 0.0783270771172829. Running F1 0.8219952670308701.
# Iteration 1200. Current Min Loss 0.07446360518690198. Running F1 0.8103366403118721.
# Iteration 1300. Current Min Loss 0.07793909806758165. Running F1 0.7962011525969726.
# Iteration 1400. Current Min Loss 0.06917925591114908. Running F1 0.8288619811560988.
# Iteration 1500. Current Min Loss 0.08034911267925055. Running F1 0.8017237765674297.
# Iteration 1600. Current Min Loss 0.09282016505370848. Running F1 0.7559060741460116.
# Iteration 1700. Current Min Loss 0.07913033890072256. Running F1 0.7856532356532352.
# Iteration 1800. Current Min Loss 0.07477499024011194. Running F1 0.8310849834719799.
# Iteration 1900. Current Min Loss 0.07765303528402001. Running F1 0.8003648260064662.
# Iteration 2000. Current Min Loss 0.0843628198094666. Running F1 0.808623703094291.
# Iteration 2100. Current Min Loss 0.07715283187106252. Running F1 0.7857547958577368.
# Iteration 2200. Current Min Loss 0.08774258755147457. Running F1 0.7961939204586257.
# Iteration 2300. Current Min Loss 0.07806836681440472. Running F1 0.7658355301389355.
# Iteration 2400. Current Min Loss 0.08349891384597868. Running F1 0.7978990157738637.
# Iteration 2500. Current Min Loss 0.07722611514152959. Running F1 0.8226129439464677.
# Iteration 2600. Current Min Loss 0.07601372088305652. Running F1 0.811506303809709.
# Iteration 2700. Current Min Loss 0.09070895049488172. Running F1 0.7709818798780969.
# Iteration 2800. Current Min Loss 0.07347757151350379. Running F1 0.8036651253802951.
# Iteration 2900. Current Min Loss 0.07782804218586534. Running F1 0.8048440812713256.
# Iteration 3000. Current Min Loss 0.07377138793468475. Running F1 0.8185697736903613.
# Iteration 3100. Current Min Loss 0.07860442330129444. Running F1 0.7811110347684646.
# Iteration 3200. Current Min Loss 0.07607486975379288. Running F1 0.7865859257701356.
# Iteration 3300. Current Min Loss 0.07438239476177841. Running F1 0.819667130684932.
# Iteration 3400. Current Min Loss 0.09341559008695186. Running F1 0.7990861573067447.
# Iteration 3500. Current Min Loss 0.07796650730073452. Running F1 0.7865940590197547.
# Iteration 3600. Current Min Loss 0.07810802439693361. Running F1 0.7823762030882765.
# Iteration 3700. Current Min Loss 0.06774093573912979. Running F1 0.7842503720050154.
# Iteration 3800. Current Min Loss 0.06870634976774453. Running F1 0.8514720583853709.
# Iteration 3900. Current Min Loss 0.07145189534407109. Running F1 0.8146003465918319.
# Iteration 4000. Current Min Loss 0.07890651332912967. Running F1 0.7690855810855807.
# Iteration 4100. Current Min Loss 0.07965545606333763. Running F1 0.8089036629752738.
# Iteration 4200. Current Min Loss 0.0723691409965977. Running F1 0.8317523228405571.
# Iteration 4300. Current Min Loss 0.07481964845210314. Running F1 0.8462210846772757.
# Iteration 4400. Current Min Loss 0.08024928322061896. Running F1 0.7908673151753643.
# Iteration 4500. Current Min Loss 0.08046531775500626. Running F1 0.8048437437175819.
# Iteration 4600. Current Min Loss 0.08792062079999596. Running F1 0.8215995929744407.
# Iteration 4700. Current Min Loss 0.07383562840521335. Running F1 0.7743973126976219.
# Iteration 4800. Current Min Loss 0.08210804240778088. Running F1 0.7920636175829666.
# Iteration 4900. Current Min Loss 0.07579311728943139. Running F1 0.7903492222880089.
# Iteration 5000. Current Min Loss 0.07893310670275241. Running F1 0.8159193831624164.
# Iteration 5100. Current Min Loss 0.07744625884573907. Running F1 0.781334554334554.
# Iteration 5200. Current Min Loss 0.0706081073032692. Running F1 0.8450452992999428.
# Iteration 5300. Current Min Loss 0.07558708118740469. Running F1 0.7639536158006003.
# Iteration 5400. Current Min Loss 0.07263122147880495. Running F1 0.8151388968377457.
# Iteration 5500. Current Min Loss 0.07819289029575885. Running F1 0.8271076335944753.
# Iteration 5600. Current Min Loss 0.075889348173514. Running F1 0.8191647527452477.
# Iteration 5700. Current Min Loss 0.07148172573652119. Running F1 0.8250336855267189.
# Iteration 5800. Current Min Loss 0.07371596860699356. Running F1 0.8067400212446646.
# Iteration 5900. Current Min Loss 0.074476871448569. Running F1 0.7871139717695443.
# Iteration 6000. Current Min Loss 0.08008341390639544. Running F1 0.8208634127758836.
# Iteration 6100. Current Min Loss 0.08193553590215742. Running F1 0.7938144717339758.
# Iteration 6200. Current Min Loss 0.08241015634965151. Running F1 0.81159415029415.
# Iteration 6300. Current Min Loss 0.07656423722393811. Running F1 0.7653356119284909.
# Iteration 6400. Current Min Loss 0.07191208757460117. Running F1 0.8457609726874431.
# Iteration 6500. Current Min Loss 0.07172499401378446. Running F1 0.8207099044746096.
# Iteration 6600. Current Min Loss 0.07049160183407366. Running F1 0.8287868221277825.
# Iteration 6700. Current Min Loss 0.08358103859238326. Running F1 0.7869245705275114.
# Iteration 6800. Current Min Loss 0.07863796005491168. Running F1 0.8255920756678594.
# Iteration 6900. Current Min Loss 0.06983639426529407. Running F1 0.8173749436837667.
# Iteration 7000. Current Min Loss 0.06449640538310632. Running F1 0.8265442645589701.
# Iteration 7100. Current Min Loss 0.07924115426256322. Running F1 0.7965652429785551.
# Iteration 7200. Current Min Loss 0.07694945553317666. Running F1 0.7871989728537712.
# Iteration 7300. Current Min Loss 0.07345005008857697. Running F1 0.8144245199245189.
# Iteration 7400. Current Min Loss 0.06617975496221334. Running F1 0.8181617108381807.
# Iteration 7500. Current Min Loss 0.07517183426069096. Running F1 0.7851711289226762.
# Iteration 7600. Current Min Loss 0.0772186239156872. Running F1 0.8143619308108468.
# vloss - 73.18345993524417
# Epoch 3.
# Iteration 100. Current Min Loss 0.0751847749738954. Running F1 0.8139772497024813.
# Iteration 200. Current Min Loss 0.07073583280667663. Running F1 0.8117469405827865.
# Iteration 300. Current Min Loss 0.08520206459797919. Running F1 0.804612955499952.
# Iteration 400. Current Min Loss 0.06995194188144524. Running F1 0.8262519237728212.
# Iteration 500. Current Min Loss 0.07850574631476775. Running F1 0.8040700858309215.
# Iteration 600. Current Min Loss 0.09337551016011275. Running F1 0.7745204450692066.
# Iteration 700. Current Min Loss 0.08207440772093832. Running F1 0.8106875394127709.
# Iteration 800. Current Min Loss 0.08526621869765222. Running F1 0.8110088801956481.
# Iteration 900. Current Min Loss 0.07935784766916186. Running F1 0.7855435153082208.
# Iteration 1000. Current Min Loss 0.07743310556281358. Running F1 0.7995207791005003.
# Iteration 1100. Current Min Loss 0.07618003904353828. Running F1 0.7889713236539855.
# Iteration 1200. Current Min Loss 0.06982163508189843. Running F1 0.8210489867179526.
# Iteration 1300. Current Min Loss 0.08729066179599614. Running F1 0.7909967487792562.
# Iteration 1400. Current Min Loss 0.07839478774927557. Running F1 0.7759886241209769.
# Iteration 1500. Current Min Loss 0.07482442206703127. Running F1 0.795735236040189.
# Iteration 1600. Current Min Loss 0.07100742036476732. Running F1 0.818791933986206.
# Iteration 1700. Current Min Loss 0.07633280106820166. Running F1 0.8050675462308585.
# Iteration 1800. Current Min Loss 0.08329172939178534. Running F1 0.8423226379227918.
# Iteration 1900. Current Min Loss 0.07843090702779591. Running F1 0.7916524992894961.
# Iteration 2000. Current Min Loss 0.07799067257437856. Running F1 0.7644334570658096.
# Iteration 2100. Current Min Loss 0.07589667558204383. Running F1 0.8033468001875925.
# Iteration 2200. Current Min Loss 0.0794522891176166. Running F1 0.8012231379731378.
# Iteration 2300. Current Min Loss 0.07626713002566249. Running F1 0.819236990391789.
# Iteration 2400. Current Min Loss 0.07673457625322044. Running F1 0.799269603805207.
# Iteration 2500. Current Min Loss 0.06585360950790346. Running F1 0.8405583909554493.
# Iteration 2600. Current Min Loss 0.0827639814838767. Running F1 0.804538565837327.
# Iteration 2700. Current Min Loss 0.0797712934575975. Running F1 0.8197722372227012.
# Iteration 2800. Current Min Loss 0.07714532998856156. Running F1 0.8179461182541001.
# Iteration 2900. Current Min Loss 0.08005690615158528. Running F1 0.8164330216567052.
# Iteration 3000. Current Min Loss 0.08236700649838895. Running F1 0.8158517036089049.
# Iteration 3100. Current Min Loss 0.09517450150102377. Running F1 0.7685638689244825.
# Iteration 3200. Current Min Loss 0.07454003402031958. Running F1 0.8273291951426622.
# Iteration 3300. Current Min Loss 0.07954159379005432. Running F1 0.8273288288527548.
# Iteration 3400. Current Min Loss 0.07511964696925133. Running F1 0.8445401388705666.
# Iteration 3500. Current Min Loss 0.0790974398702383. Running F1 0.8060170948762275.
# Iteration 3600. Current Min Loss 0.07838055903557688. Running F1 0.7973941248809665.
# Iteration 3700. Current Min Loss 0.08299755932763218. Running F1 0.8062355686796859.
# Iteration 3800. Current Min Loss 0.07136849186383187. Running F1 0.8246948721213424.
# Iteration 3900. Current Min Loss 0.07655540362931788. Running F1 0.8058465546321577.
# Iteration 4000. Current Min Loss 0.07719035969115794. Running F1 0.7684960050269645.
# Iteration 4100. Current Min Loss 0.07467321182251908. Running F1 0.8330846569599764.
# Iteration 4200. Current Min Loss 0.07732216473901644. Running F1 0.7974010660821801.
# Iteration 4300. Current Min Loss 0.08809548169374466. Running F1 0.7639749972249965.
# Iteration 4400. Current Min Loss 0.07425866037141532. Running F1 0.8151877581482839.
# Iteration 4500. Current Min Loss 0.08440324660856277. Running F1 0.8047420847126726.
# Iteration 4600. Current Min Loss 0.07780133056454361. Running F1 0.7775662473061847.
# Iteration 4700. Current Min Loss 0.07480676084291189. Running F1 0.8020733776027891.
# Iteration 4800. Current Min Loss 0.06876172749325633. Running F1 0.8332121510240702.
# Iteration 4900. Current Min Loss 0.07267507672775536. Running F1 0.7944463322643756.
# Iteration 5000. Current Min Loss 0.07095288332551718. Running F1 0.7966080427140793.
# Iteration 5100. Current Min Loss 0.08603916568681598. Running F1 0.7775062484814798.
# Iteration 5200. Current Min Loss 0.07368744378443808. Running F1 0.8211593635982177.
# Iteration 5300. Current Min Loss 0.07363982297945768. Running F1 0.8153806797777381.
# Iteration 5400. Current Min Loss 0.06085481629241258. Running F1 0.8205981453187329.
# Iteration 5500. Current Min Loss 0.07708799156360328. Running F1 0.8167093609864503.
# Iteration 5600. Current Min Loss 0.07402539868839085. Running F1 0.8236676246869742.
# Iteration 5700. Current Min Loss 0.07779982993844897. Running F1 0.7827323624088326.
# Iteration 5800. Current Min Loss 0.07414745787158608. Running F1 0.8046840665504006.
# Iteration 5900. Current Min Loss 0.07009856139076874. Running F1 0.8500111818350199.
# Iteration 6000. Current Min Loss 0.0772462503798306. Running F1 0.8217047933595246.
# Iteration 6100. Current Min Loss 0.07923778479918837. Running F1 0.793841543905011.
# Iteration 6200. Current Min Loss 0.07465636217035353. Running F1 0.8061699542287775.
# Iteration 6300. Current Min Loss 0.07162213495932519. Running F1 0.7962885278636045.
# Iteration 6400. Current Min Loss 0.07996818181825802. Running F1 0.7667674824315688.
# Iteration 6500. Current Min Loss 0.08277584093622864. Running F1 0.7973854999489671.
# Iteration 6600. Current Min Loss 0.0706649037450552. Running F1 0.8554681625563971.
# Iteration 6700. Current Min Loss 0.07108766231685877. Running F1 0.821330248011362.
# Iteration 6800. Current Min Loss 0.07909918250516057. Running F1 0.8065011160039617.
# Iteration 6900. Current Min Loss 0.07160808425862342. Running F1 0.8309298407990353.
# Iteration 7000. Current Min Loss 0.08342355855740607. Running F1 0.7881617775928917.
# Iteration 7100. Current Min Loss 0.07833904584869743. Running F1 0.8236261791632629.
# Iteration 7200. Current Min Loss 0.0704710731934756. Running F1 0.8068446112710813.
# Iteration 7300. Current Min Loss 0.07097742496058344. Running F1 0.8468631287013634.
# Iteration 7400. Current Min Loss 0.07165607934817672. Running F1 0.8290545195545191.
# Iteration 7500. Current Min Loss 0.0829519540257752. Running F1 0.8198089658019997.
# Iteration 7600. Current Min Loss 0.07317990985931828. Running F1 0.8439552184141965.
# vloss - 86.53275124967331
# Epoch 4.
# Iteration 100. Current Min Loss 0.08378060796298087. Running F1 0.8078684528405888.
# Iteration 200. Current Min Loss 0.08399110537779052. Running F1 0.7882686235333289.
# Iteration 300. Current Min Loss 0.07802463518455624. Running F1 0.8073860224742575.
# Iteration 400. Current Min Loss 0.0870961350388825. Running F1 0.8064054059115974.
# Iteration 500. Current Min Loss 0.0768781702965498. Running F1 0.7441140661024557.
# Iteration 600. Current Min Loss 0.08468717721756548. Running F1 0.7788974475816576.
# Iteration 700. Current Min Loss 0.07847032006597146. Running F1 0.8449598687174532.
# Iteration 800. Current Min Loss 0.0803531442862004. Running F1 0.8135407305113184.
# Iteration 900. Current Min Loss 0.06942957701161503. Running F1 0.8572803384266223.
# Iteration 1000. Current Min Loss 0.07285518436692655. Running F1 0.8152028559675614.
# Iteration 1100. Current Min Loss 0.07751542191952467. Running F1 0.8228535463332675.
# Iteration 1200. Current Min Loss 0.07617808874696493. Running F1 0.8316569764085239.
# Iteration 1300. Current Min Loss 0.07403388566919603. Running F1 0.8308335449380335.
# Iteration 1400. Current Min Loss 0.06910339864902199. Running F1 0.8128995429235362.
# Iteration 1500. Current Min Loss 0.07852912906091661. Running F1 0.8016288270552968.
# Iteration 1600. Current Min Loss 0.07866613416932523. Running F1 0.7852060917238934.
# Iteration 1700. Current Min Loss 0.07502837128005922. Running F1 0.8427239198709779.
# Iteration 1800. Current Min Loss 0.0752089810045436. Running F1 0.817251595239985.
# Iteration 1900. Current Min Loss 0.0747645074641332. Running F1 0.8022669093481108.
# Iteration 2000. Current Min Loss 0.07763408336788416. Running F1 0.7941397908077467.
# Iteration 2100. Current Min Loss 0.07850709552876652. Running F1 0.795146623843992.
# Iteration 2200. Current Min Loss 0.07267026825807989. Running F1 0.8152976935345353.
# Iteration 2300. Current Min Loss 0.08211905177216977. Running F1 0.7766586877175109.
# Iteration 2400. Current Min Loss 0.08061187023296952. Running F1 0.7950617944147349.
# Iteration 2500. Current Min Loss 0.07765498992521316. Running F1 0.819242564624917.
# Iteration 2600. Current Min Loss 0.08467217052006162. Running F1 0.8083388213094089.
# Iteration 2700. Current Min Loss 0.07210274587385357. Running F1 0.8200409702956136.
# Iteration 2800. Current Min Loss 0.07951153322588653. Running F1 0.7967906275011533.
# Iteration 2900. Current Min Loss 0.07869402300566435. Running F1 0.833439358886727.
# Iteration 3000. Current Min Loss 0.08490903547033668. Running F1 0.7798718745135147.
# Iteration 3100. Current Min Loss 0.06967133750673384. Running F1 0.8330645481969006.
# Iteration 3200. Current Min Loss 0.07219189772382378. Running F1 0.7968836304734132.
# Iteration 3300. Current Min Loss 0.0814865251723677. Running F1 0.7945919940053063.
# Iteration 3400. Current Min Loss 0.08653300705365836. Running F1 0.7847362309173449.
# Iteration 3500. Current Min Loss 0.08083974375389516. Running F1 0.8150650212360732.
# Iteration 3600. Current Min Loss 0.07970256650238298. Running F1 0.8005753259468427.
# Iteration 3700. Current Min Loss 0.081431093942374. Running F1 0.8111709099443648.
# Iteration 3800. Current Min Loss 0.07335968853905797. Running F1 0.7948906336630115.
# Iteration 3900. Current Min Loss 0.0817514012628817. Running F1 0.8139163826369706.
# Iteration 4000. Current Min Loss 0.07784288472495973. Running F1 0.7999585943811944.
# Iteration 4100. Current Min Loss 0.08979557312093675. Running F1 0.8104356830819676.
# Iteration 4200. Current Min Loss 0.08804980189539492. Running F1 0.777147132107658.
# Iteration 4300. Current Min Loss 0.07333118844544514. Running F1 0.8093874891467091.
# Iteration 4400. Current Min Loss 0.06526106300763786. Running F1 0.8378301698301692.
# Iteration 4500. Current Min Loss 0.0868582805711776. Running F1 0.8047645459975176.
# Iteration 4600. Current Min Loss 0.07464615997392685. Running F1 0.8090806437972066.
# Iteration 4700. Current Min Loss 0.07559159382712095. Running F1 0.826069618219234.
# Iteration 4800. Current Min Loss 0.07433479223866016. Running F1 0.8097016260313467.
# Iteration 4900. Current Min Loss 0.07499519699718803. Running F1 0.8007539045921395.
# Iteration 5000. Current Min Loss 0.07379711896879598. Running F1 0.8180123585564759.
# Iteration 5100. Current Min Loss 0.0726130153296981. Running F1 0.7839949217449217.
# Iteration 5200. Current Min Loss 0.07652181490324438. Running F1 0.8208410816050129.
# Iteration 5300. Current Min Loss 0.07925812039524317. Running F1 0.7958333811870957.
# Iteration 5400. Current Min Loss 0.08375088482163846. Running F1 0.7809080755845459.
# Iteration 5500. Current Min Loss 0.07159551884513349. Running F1 0.8269503860432649.
# Iteration 5600. Current Min Loss 0.07419373521581292. Running F1 0.7936563354945702.
# Iteration 5700. Current Min Loss 0.08530623672762885. Running F1 0.7951380008880006.
# Iteration 5800. Current Min Loss 0.06526444548740983. Running F1 0.8377467571987691.
# Iteration 5900. Current Min Loss 0.07482259274460375. Running F1 0.7878621697360083.
# Iteration 6000. Current Min Loss 0.07111487859860062. Running F1 0.8088571526512699.
# Iteration 6100. Current Min Loss 0.0924931934569031. Running F1 0.7581824611576927.
# Iteration 6200. Current Min Loss 0.13010241691954433. Running F1 0.6828336607836605.
# Iteration 6300. Current Min Loss 0.08629480937030166. Running F1 0.8143216064980764.
# Iteration 6400. Current Min Loss 0.11728541809134185. Running F1 0.7372290691764369.
# Iteration 6500. Current Min Loss 0.1545194250717759. Running F1 0.6798963830287356.
# Iteration 6600. Current Min Loss 0.21157053848495708. Running F1 0.18095154845154848.
# Iteration 6700. Current Min Loss 0.11701863983646035. Running F1 0.7810263188823556.
# Iteration 6800. Current Min Loss 0.08107783490326255. Running F1 0.8204433344433341.
# Iteration 6900. Current Min Loss 0.0921309228055179. Running F1 0.7904677036929357.
# Iteration 7000. Current Min Loss 0.12016170834191144. Running F1 0.7430242353965258.
# Iteration 7100. Current Min Loss 0.11163923179730773. Running F1 0.765113399500396.
# Iteration 7200. Current Min Loss 0.07815984161337837. Running F1 0.821169678017201.
# Iteration 7300. Current Min Loss 0.10150094666518271. Running F1 0.7694270484417537.
# Iteration 7400. Current Min Loss 0.08831542415544391. Running F1 0.7876210585080549.
# Iteration 7500. Current Min Loss 0.10119643337558955. Running F1 0.7608651742993843.
# Iteration 7600. Current Min Loss 0.07266101425047963. Running F1 0.8148280347103872.
# vloss - 95.63312392216176

# %%
with open("losses/LossWithComments", "wb") as fb:
    pickle.dump(train_losses, fb)
